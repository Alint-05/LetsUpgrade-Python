# %% [markdown]
# <a href="https://colab.research.google.com/github/Alint-05/LetsUpgrade-Python/blob/master/day_3_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alt=input("Enter the altitude - ")
alt=int(alt)
# Out:
# Enter the altitude - 3000

# %%
if alt <= 1000:
  print("Safe To Land")
elif alt > 1000 and alt <= 5000:
  print("Bring Down")
elif alt > 5000:
  print("Turn Around ")
# Out:
# Bring Down
