# %% [markdown]
# <a href="https://colab.research.google.com/github/Alint-05/LetsUpgrade-Python/blob/master/Day_2_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **LIST**

# %%
lst = ["Alint", 20]

# %%
lst
# Out:
# ['Alint', 20]

# %%
lst.append("alint@gmail.com")

# %%
lst
# Out:
# ['Alint', 20, 'alint@gmail.com']

# %%
lst.extend([90, [1,5,6]])

# %%
lst
# Out:
# ['Alint', 20, 'alint@gmail.com', 90, [1, 5, 6]]

# %%
lst.insert(1, "Saji")

# %%
lst
# Out:
# ['Alint', 'Saji', 20, 'alint@gmail.com', 90, [1, 5, 6]]

# %%
lst.remove("Saji")

# %%
lst
# Out:
# ['Alint', 20, 'alint@gmail.com', 90, [1, 5, 6]]

# %%
lst.pop()
# Out:
# [1, 5, 6]

# %%
lst.clear()

# %%
lst
# Out:
# []

# %% [markdown]
# # **DIC**

# %%
dit = {"name":"ALINT", "age":"20", "LOCATION":"KERALA"}

# %%
dit
# Out:
# {'LOCATION': 'KERALA', 'age': '20', 'name': 'ALINT'}

# %%
dit.get("name")
# Out:
# 'ALINT'

# %%
dit.values()
# Out:
# dict_values(['ALINT', '20', 'KERALA'])

# %%
dit.keys()
# Out:
# dict_keys(['name', 'age', 'LOCATION'])

# %%
y = ("LA")
dit.fromkeys(dit,y)
# Out:
# {'LOCATION': 'LA', 'age': 'LA', 'name': 'LA'}

# %%
dit.update({"College" : "St.Teresa's "})

# %%
dit
# Out:
# {'College': "St.Teresa's ", 'LOCATION': 'KERALA', 'age': '20', 'name': 'ALINT'}

# %% [markdown]
# ## **SET**

# %%
s = {"Alint" , "Saji"  , 90, 45, 88 }

# %%
s
# Out:
# {45, 88, 90, 'Alint', 'Saji'}

# %%
s1 = { 3, "Alint"}

# %%
s1.issubset(s)
# Out:
# False

# %%
s1.intersection(s)
# Out:
# {'Alint'}

# %%
s1.difference(s)
# Out:
# {3}

# %%
s1.add("Kerala")

# %%
s1
# Out:
# {3, 'Alint', 'Kerala'}

# %%
s1.update(["kerala" , "wayanad" , "mananthavaday"])

# %%
s1
# Out:
# {3, 'Alint', 'Kerala', 'kerala', 'mananthavaday', 'wayanad'}

# %% [markdown]
# # **TUPLE**

# %%
tup = ("Alint" ,"Saji" ,90,99,87 )

# %%
tup
# Out:
# ('Alint', 'Saji', 90, 99, 87)

# %%
tup.count(1)
# Out:
# 0

# %%
tup.index(90)
# Out:
# 2

# %% [markdown]
# # **STRINGS**

# %%
str = "hello world"

# %%
str
# Out:
# 'hello world'

# %%
str.capitalize()
# Out:
# 'Hello world'

# %%
str.encode()
# Out:
# b'hello world'

# %%
str.find("l")
# Out:
# 2

# %%
str.upper()
# Out:
# 'HELLO WORLD'
